# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('reduced_well_milled_rice.csv')
df.MONTH = df.MONTH.astype(int)
df["DATE"] = pd.to_datetime(df.YEAR.astype(str) + '/' + df.MONTH.astype(str) + '/01')
df = df.set_index('DATE').asfreq('MS')

# %%
df = df.iloc[:, 3:4]

# %%
df
# Out:
#             Price / kg
# DATE
# 1990-01-01        9.50
# 1990-02-01        9.00
# 1990-03-01        9.00
# 1990-04-01        9.65
# 1990-05-01        9.70
# ...                ...
# 2020-08-01       46.67
# 2020-09-01       45.33
# 2020-10-01       44.92
# 2020-11-01       41.29
# 2020-12-01       42.49
#
# [372 rows x 1 columns]

# %%
df.shape
# Out:
# (372, 1)

# %%
df.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='DATE'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Run seasonal decomposition again
results = seasonal_decompose(df)
results.plot();

# %%
len(df)
# Out:
# 372

# %%
train = df.iloc[:-12]
test = df.iloc[-12:]

# %%
print(f"Train Shape: {train.shape} and Test Shape: {test.shape}")
# Out:
# Train Shape: (360, 1) and Test Shape: (12, 1)

# %%
test
# Out:
#             Price / kg
# DATE
# 2023-08-01       48.67
# 2023-09-01       55.00
# 2023-10-01       54.75
# 2023-11-01       55.74
# 2023-12-01       56.17
# 2024-01-01       56.76
# 2024-02-01       57.14
# 2024-03-01       57.56
# 2024-04-01       60.02
# 2024-05-01       60.02
# 2024-06-01       60.02
# 2024-07-01       60.02

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df.head(),df.tail()
# Out:
# (            Price / kg
#  DATE
#  1990-01-01        9.50
#  1990-02-01        9.00
#  1990-03-01        9.00
#  1990-04-01        9.65
#  1990-05-01        9.70,
#              Price / kg
#  DATE
#  2024-03-01       57.56
#  2024-04-01       60.02
#  2024-05-01       60.02
#  2024-06-01       60.02
#  2024-07-01       60.02)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
original_value = scaler.inverse_transform(scaled_train)
original_value
# Out:
# array([[ 9.5 ],
#        [ 9.  ],
#        [ 9.  ],
#        [ 9.65],
#        [ 9.7 ],
#        [ 9.7 ],
#        [ 9.7 ],
#        [ 9.7 ],
#        [ 9.7 ],
#        [ 9.55],
#        [ 9.6 ],
#        [10.  ],
#        [10.5 ],
#        [10.5 ],
#        [10.  ],
#        [ 9.6 ],
#        [ 9.6 ],
#        [ 9.6 ],
#        [ 9.7 ],
#        [ 9.9 ],
#        [ 9.5 ],
#        [ 9.4 ],
#        [ 9.2 ],
#        [ 9.2 ],
#        [ 9.4 ],
#        [ 9.3 ],
#        [ 9.4 ],
#        [ 9.65],
#        [10.45],
#        [10.4 ],
#        [11.5 ],
#        [12.  ],
#        [12.  ],
#        [10.8 ],
#        [11.  ],
#        [11.  ],
#        [11.5 ],
#        [11.5 ],
#        [11.5 ],
#        [11.5 ],
#        [11.8 ],
#        [11.8 ],
#        [12.  ],
#        [12.5 ],
#        [12.8 ],
#        [12.5 ],
#        [12.5 ],
#        [12.  ],
#        [12.5 ],
#        [12.5 ],
#        [12.5 ],
#        [13.  ],
#        [13.  ],
#        [13.  ],
#        [13.4 ],
#        [14.  ],
#        [14.  ],
#        [13.5 ],
#        [13.5 ],
#        [13.8 ],
#        [13.8 ],
#        [14.  ],
#        [14.  ],
#        [14.5 ],
#        [15.9 ],
#        [16.  ],
#        [16.5 ],
#        [19.  ],
#        [19.5 ],
#        [18.85],
#        [18.25],
#        [17.  ],
#        [18.6 ],
#        [19.5 ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.2 ],
#        [19.5 ],
#        [19.4 ],
#        [18.75],
#        [18.5 ],
#        [18.  ],
#        [18.  ],
#        [18.6 ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.2 ],
#        [18.5 ],
#        [18.1 ],
#        [18.5 ],
#        [18.75],
#        [18.5 ],
#        [18.2 ],
#        [18.  ],
#        [18.1 ],
#        [18.5 ],
#        [18.5 ],
#        [18.5 ],
#        [18.5 ],
#        [18.6 ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [18.8 ],
#        [18.5 ],
#        [18.5 ],
#        [18.9 ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.25],
#        [19.1 ],
#        [18.8 ],
#        [20.  ],
#        [18.5 ],
#        [18.  ],
#        [19.5 ],
#        [19.45],
#        [18.3 ],
#        [18.  ],
#        [18.5 ],
#        [20.2 ],
#        [19.75],
#        [19.2 ],
#        [18.25],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.6 ],
#        [18.5 ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.  ],
#        [18.5 ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [19.  ],
#        [20.  ],
#        [21.5 ],
#        [22.  ],
#        [22.25],
#        [22.8 ],
#        [23.  ],
#        [22.25],
#        [21.6 ],
#        [21.5 ],
#        [22.  ],
#        [22.  ],
#        [22.25],
#        [23.  ],
#        [24.  ],
#        [24.  ],
#        [24.  ],
#        [24.  ],
#        [24.  ],
#        [24.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.  ],
#        [23.38],
#        [24.3 ],
#        [25.25],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [25.  ],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [26.  ],
#        [26.75],
#        [27.  ],
#        [27.  ],
#        [27.  ],
#        [27.  ],
#        [27.  ],
#        [27.  ],
#        [27.  ],
#        [33.75],
#        [35.25],
#        [40.2 ],
#        [38.75],
#        [36.  ],
#        [33.5 ],
#        [33.  ],
#        [33.8 ],
#        [34.  ],
#        [33.8 ],
#        [36.  ],
#        [36.25],
#        [36.  ],
#        [36.  ],
#        [36.  ],
#        [36.  ],
#        [35.5 ],
#        [35.  ],
#        [35.  ],
#        [35.25],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [34.8 ],
#        [34.  ],
#        [34.  ],
#        [34.8 ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [34.5 ],
#        [34.  ],
#        [34.25],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.  ],
#        [35.75],
#        [36.25],
#        [34.8 ],
#        [34.75],
#        [35.75],
#        [36.  ],
#        [36.25],
#        [36.  ],
#        [36.  ],
#        [35.5 ],
#        [35.  ],
#        [35.4 ],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [37.75],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.17],
#        [42.13],
#        [42.13],
#        [42.13],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.  ],
#        [42.  ],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.25],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [42.38],
#        [45.75],
#        [45.75],
#        [46.11],
#        [45.75],
#        [45.75],
#        [45.75],
#        [46.83],
#        [52.48],
#        [55.98],
#        [56.79],
#        [54.91],
#        [55.18],
#        [54.1 ],
#        [53.02],
#        [52.35],
#        [52.35],
#        [52.35],
#        [52.08],
#        [51.67],
#        [51.4 ],
#        [51.13],
#        [50.46],
#        [50.19],
#        [49.51],
#        [48.3 ],
#        [47.49],
#        [46.41],
#        [46.41],
#        [48.15],
#        [47.88],
#        [47.21],
#        [46.67],
#        [45.33],
#        [44.92],
#        [41.29],
#        [42.49],
#        [42.76],
#        [43.44],
#        [43.44],
#        [43.3 ],
#        [43.05],
#        [43.57],
#        [45.  ],
#        [45.  ],
#        [45.67],
#        [45.67],
#        [43.5 ],
#        [43.75],
#        [43.33],
#        [42.5 ],
#        [41.67],
#        [41.58],
#        [42.08],
#        [42.25],
#        [42.67],
#        [42.42],
#        [42.92],
#        [42.58],
#        [42.58],
#        [42.5 ],
#        [42.5 ],
#        [42.33],
#        [41.75],
#        [43.17],
#        [44.  ],
#        [44.5 ],
#        [44.5 ]])

# %%
scaled_train[:80]
# Out:
# array([[0.01046244],
#        [0.        ],
#        [0.        ],
#        [0.01360117],
#        [0.01464742],
#        [0.01464742],
#        [0.01464742],
#        [0.01464742],
#        [0.01464742],
#        [0.01150868],
#        [0.01255493],
#        [0.02092488],
#        [0.03138732],
#        [0.03138732],
#        [0.02092488],
#        [0.01255493],
#        [0.01255493],
#        [0.01255493],
#        [0.01464742],
#        [0.01883239],
#        [0.01046244],
#        [0.00836995],
#        [0.00418498],
#        [0.00418498],
#        [0.00836995],
#        [0.00627746],
#        [0.00836995],
#        [0.01360117],
#        [0.03034108],
#        [0.02929483],
#        [0.0523122 ],
#        [0.06277464],
#        [0.06277464],
#        [0.03766478],
#        [0.04184976],
#        [0.04184976],
#        [0.0523122 ],
#        [0.0523122 ],
#        [0.0523122 ],
#        [0.0523122 ],
#        [0.05858966],
#        [0.05858966],
#        [0.06277464],
#        [0.07323708],
#        [0.07951454],
#        [0.07323708],
#        [0.07323708],
#        [0.06277464],
#        [0.07323708],
#        [0.07323708],
#        [0.07323708],
#        [0.08369952],
#        [0.08369952],
#        [0.08369952],
#        [0.09206947],
#        [0.1046244 ],
#        [0.1046244 ],
#        [0.09416196],
#        [0.09416196],
#        [0.10043942],
#        [0.10043942],
#        [0.1046244 ],
#        [0.1046244 ],
#        [0.11508684],
#        [0.14438167],
#        [0.14647416],
#        [0.1569366 ],
#        [0.2092488 ],
#        [0.21971124],
#        [0.20611006],
#        [0.19355514],
#        [0.16739904],
#        [0.20087884],
#        [0.21971124],
#        [0.2092488 ],
#        [0.2092488 ],
#        [0.2092488 ],
#        [0.21343377],
#        [0.21971124],
#        [0.21761875]])

# %%
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator 
n_input = 402
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
# Get the first batch
X, y = generator[0]

# Reshape X to 2D for inverse transformation
# X shape is (1, n_input, n_features)
X_reshaped = X.reshape(-1, 1)  # This will make it (n_input, n_features)

# Inverse transform to get original values
original_values = scaler.inverse_transform(X_reshaped)

# Print results
print(f'Given the Array (scaled): \n{X.flatten()}')
print(f'Original values: \n{original_values.flatten()}')
# Out:
# Given the Array (scaled):
# [0.01046244 0.         0.         0.01360117 0.01464742 0.01464742
#  0.01464742 0.01464742 0.01464742 0.01150868 0.01255493 0.02092488
#  0.03138732 0.03138732 0.02092488 0.01255493 0.01255493 0.01255493
#  0.01464742 0.01883239 0.01046244 0.00836995 0.00418498 0.00418498
#  0.00836995 0.00627746 0.00836995 0.01360117 0.03034108 0.02929483
#  0.0523122  0.06277464 0.06277464 0.03766478 0.04184976 0.04184976
#  0.0523122  0.0523122  0.0523122  0.0523122  0.05858966 0.05858966
#  0.06277464 0.07323708 0.07951454 0.07323708 0.07323708 0.06277464
#  0.07323708 0.07323708 0.07323708 0.08369952 0.08369952 0.08369952
#  0.09206947 0.1046244  0.1046244  0.09416196 0.09416196 0.10043942
#  0.10043942 0.1046244  0.1046244  0.11508684 0.14438167 0.14647416
#  0.1569366  0.2092488  0.21971124 0.20611006 0.19355514 0.16739904
#  0.20087884 0.21971124 0.2092488  0.2092488  0.2092488  0.21343377
#  0.21971124 0.21761875 0.20401758 0.19878636 0.18832392 0.18832392
#  0.20087884 0.18832392 0.18832392 0.18832392 0.19250889 0.19878636
#  0.19041641 0.19878636 0.20401758 0.19878636 0.19250889 0.18832392
#  0.19041641 0.19878636 0.19878636 0.19878636 0.19878636 0.20087884
#  0.2092488  0.2092488  0.2092488  0.20506382 0.19878636 0.19878636
#  0.20715631 0.2092488  0.2092488  0.2092488  0.2092488  0.2092488
#  0.2092488  0.21448002 0.21134128 0.20506382 0.23017368 0.19878636
#  0.18832392 0.21971124 0.21866499 0.19460138 0.18832392 0.19878636
#  0.23435865 0.22494246 0.21343377 0.19355514 0.18832392 0.18832392
#  0.18832392 0.18832392 0.18832392 0.18832392 0.18832392 0.18832392
#  0.18832392 0.18832392 0.18832392 0.18832392 0.18832392 0.18832392
#  0.18832392 0.18832392 0.18832392 0.18832392 0.18832392 0.18832392
#  0.18832392 0.20087884 0.19878636 0.18832392 0.18832392 0.18832392
#  0.18832392 0.18832392 0.18832392 0.19878636 0.2092488  0.2092488
#  0.2092488  0.2092488  0.2092488  0.2092488  0.2092488  0.2092488
#  0.2092488  0.2092488  0.23017368 0.261561   0.27202344 0.27725466
#  0.28876334 0.29294832 0.27725466 0.26365348 0.261561   0.27202344
#  0.27202344 0.27725466 0.29294832 0.3138732  0.3138732  0.3138732
#  0.3138732  0.3138732  0.3138732  0.29294832 0.29294832 0.29294832
#  0.29294832 0.29294832 0.29294832 0.29294832 0.29294832 0.30089977
#  0.32015066 0.34002929 0.35572295 0.35572295 0.35572295 0.33479807
#  0.35572295 0.35572295 0.35572295 0.35572295 0.35572295 0.35572295
#  0.35572295 0.37141661 0.37664783 0.37664783 0.37664783 0.37664783
#  0.37664783 0.37664783 0.37664783 0.51789077 0.54927809 0.65285625
#  0.62251517 0.56497175 0.51265955 0.50219711 0.51893702 0.52312199
#  0.51893702 0.56497175 0.57020297 0.56497175 0.56497175 0.56497175
#  0.56497175 0.55450931 0.54404687 0.54404687 0.54927809 0.54404687
#  0.54404687 0.54404687 0.54404687 0.54404687 0.54404687 0.54404687
#  0.54404687 0.54404687 0.54404687 0.5398619  0.52312199 0.52312199
#  0.5398619  0.54404687 0.54404687 0.54404687 0.54404687 0.53358443
#  0.52312199 0.52835321 0.54404687 0.54404687 0.54404687 0.54404687
#  0.55974053 0.57020297 0.5398619  0.53881565 0.55974053 0.56497175
#  0.57020297 0.56497175 0.56497175 0.55450931 0.54404687 0.55241682
#  0.60159029 0.60159029 0.60159029 0.60159029 0.60159029 0.60159029
#  0.60159029 0.60159029 0.60159029 0.60159029 0.60159029 0.60159029
#  0.69324126 0.69324126 0.69324126 0.69324126 0.69324126 0.69324126
#  0.69324126 0.69324126 0.69324126 0.69324126 0.69324126 0.69407826
#  0.69324126 0.69324126 0.69324126 0.69575225 0.69575225 0.69575225
#  0.69575225 0.69575225 0.69575225 0.69575225 0.69575225 0.69052103
#  0.69052103 0.69575225 0.69575225 0.69575225 0.69575225 0.69575225
#  0.69575225 0.69575225 0.69575225 0.69575225 0.69575225 0.69575225
#  0.69847248 0.69847248 0.69847248 0.69847248 0.69847248 0.69847248
#  0.69847248 0.69847248 0.69847248 0.69847248 0.69847248 0.69847248
#  0.76898933 0.76898933 0.77652228 0.76898933 0.76898933 0.76898933
#  0.7915882  0.90981377 0.98305085 1.         0.96066123 0.96631094
#  0.94371207 0.9211132  0.90709353 0.90709353 0.90709353 0.90144382
#  0.89286462 0.8872149  0.88156518 0.86754551 0.86189579 0.84766688
#  0.82234777 0.80539862 0.78279975 0.78279975 0.81920904 0.81355932
#  0.79953965 0.78824022 0.76020088 0.75162168 0.67566436 0.70077422
#  0.70642394 0.72065286 0.72065286 0.71772337 0.71249215 0.72337309
#  0.75329567 0.75329567 0.76731534 0.76731534 0.72190835 0.72713957
#  0.71835112 0.70098347 0.68361582 0.68173258 0.69219502 0.69575225
#  0.7045407  0.69930948 0.70977192 0.70265746 0.70265746 0.70098347
#  0.70098347 0.69742624 0.68528981 0.71500314 0.73237079 0.74283323]
# Original values:
# [ 9.5   9.    9.    9.65  9.7   9.7   9.7   9.7   9.7   9.55  9.6  10.
#  10.5  10.5  10.    9.6   9.6   9.6   9.7   9.9   9.5   9.4   9.2   9.2
#   9.4   9.3   9.4   9.65 10.45 10.4  11.5  12.   12.   10.8  11.   11.
#  11.5  11.5  11.5  11.5  11.8  11.8  12.   12.5  12.8  12.5  12.5  12.
#  12.5  12.5  12.5  13.   13.   13.   13.4  14.   14.   13.5  13.5  13.8
#  13.8  14.   14.   14.5  15.9  16.   16.5  19.   19.5  18.85 18.25 17.
#  18.6  19.5  19.   19.   19.   19.2  19.5  19.4  18.75 18.5  18.   18.
#  18.6  18.   18.   18.   18.2  18.5  18.1  18.5  18.75 18.5  18.2  18.
#  18.1  18.5  18.5  18.5  18.5  18.6  19.   19.   19.   18.8  18.5  18.5
#  18.9  19.   19.   19.   19.   19.   19.   19.25 19.1  18.8  20.   18.5
#  18.   19.5  19.45 18.3  18.   18.5  20.2  19.75 19.2  18.25 18.   18.
#  18.   18.   18.   18.   18.   18.   18.   18.   18.   18.   18.   18.
#  18.   18.   18.   18.   18.   18.   18.   18.6  18.5  18.   18.   18.
#  18.   18.   18.   18.5  19.   19.   19.   19.   19.   19.   19.   19.
#  19.   19.   20.   21.5  22.   22.25 22.8  23.   22.25 21.6  21.5  22.
#  22.   22.25 23.   24.   24.   24.   24.   24.   24.   23.   23.   23.
#  23.   23.   23.   23.   23.   23.38 24.3  25.25 26.   26.   26.   25.
#  26.   26.   26.   26.   26.   26.   26.   26.75 27.   27.   27.   27.
#  27.   27.   27.   33.75 35.25 40.2  38.75 36.   33.5  33.   33.8  34.
#  33.8  36.   36.25 36.   36.   36.   36.   35.5  35.   35.   35.25 35.
#  35.   35.   35.   35.   35.   35.   35.   35.   35.   34.8  34.   34.
#  34.8  35.   35.   35.   35.   34.5  34.   34.25 35.   35.   35.   35.
#  35.75 36.25 34.8  34.75 35.75 36.   36.25 36.   36.   35.5  35.   35.4
#  37.75 37.75 37.75 37.75 37.75 37.75 37.75 37.75 37.75 37.75 37.75 37.75
#  42.13 42.13 42.13 42.13 42.13 42.13 42.13 42.13 42.13 42.13 42.13 42.17
#  42.13 42.13 42.13 42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.
#  42.   42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.25 42.25
#  42.38 42.38 42.38 42.38 42.38 42.38 42.38 42.38 42.38 42.38 42.38 42.38
#  45.75 45.75 46.11 45.75 45.75 45.75 46.83 52.48 55.98 56.79 54.91 55.18
#  54.1  53.02 52.35 52.35 52.35 52.08 51.67 51.4  51.13 50.46 50.19 49.51
#  48.3  47.49 46.41 46.41 48.15 47.88 47.21 46.67 45.33 44.92 41.29 42.49
#  42.76 43.44 43.44 43.3  43.05 43.57 45.   45.   45.67 45.67 43.5  43.75
#  43.33 42.5  41.67 41.58 42.08 42.25 42.67 42.42 42.92 42.58 42.58 42.5
#  42.5  42.33 41.75 43.17 44.   44.5 ]

# %%
y_reshaped = y.reshape(-1, 1)  # This will make it (n_input, n_features)

# Inverse transform to get original values
original_values = scaler.inverse_transform(y_reshaped)

print(f'Predict this y: \n {y} \n')
print(f'Original values: \n{original_values.flatten()}')
# Out:
# Predict this y:
#  [[0.74283323]]
#
# Original values:
# [44.5]

# %%
X.shape
# Out:
# (1, 402, 1)

# %%
# We do the same thing, but now instead for 12 months
#n_input = 12
#generator = TimeseriesGenerator(scaled_train[:, 1:2], scaled_train[:, 1:2], length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# C:\Users\Krystel\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit model
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 0.6052
# Epoch 2/50
# C:\Users\Krystel\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.5503
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.4982
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.4480
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.3999
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.3553
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.3117
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2692
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.2281
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1878
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.1494
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1110
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0740
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0361
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0027
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2626
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0099
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 3.2514e-04
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0069
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0155
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0236
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.0307
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0366
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0415
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0455
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0484
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0505
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0518
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0525
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0525
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0520
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0510
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0495
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0477
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0455
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0429
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - loss: 0.0400
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0369
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0336
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0301
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0264
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0226
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.0188
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0150
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0112
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - loss: 0.0077
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0046
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0021
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 4.7249e-04
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 1.8725e-05

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-402:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# array([[0.7764356]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.83008998])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
test_predictions
# Out:
# [array([0.7764356], dtype=float32),
#  array([0.78268987], dtype=float32),
#  array([0.78883857], dtype=float32),
#  array([0.7951576], dtype=float32),
#  array([0.8016562], dtype=float32),
#  array([0.8083386], dtype=float32),
#  array([0.81521165], dtype=float32),
#  array([0.8222836], dtype=float32),
#  array([0.82956415], dtype=float32),
#  array([0.83706385], dtype=float32),
#  array([0.84479463], dtype=float32),
#  array([0.852769], dtype=float32)]

# %%
test.head()
# Out:
#             Price / kg
# DATE
# 2023-08-01       48.67
# 2023-09-01       55.00
# 2023-10-01       54.75
# 2023-11-01       55.74
# 2023-12-01       56.17

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# C:\Users\Krystel\AppData\Local\Temp\ipykernel_13612\4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test["Price / kg"].plot(figsize=(14,5))
# Out:
# <Axes: xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from math import sqrt

# Calculate RMSE
rmse = sqrt(mean_squared_error(test['Price / kg'], test['Predictions']))
print(f'RMSE: {rmse}')

# Calculate MSE
mse = mean_squared_error(test['Price / kg'], test['Predictions'])
print(f'MSE: {mse}')

# Calculate MAE
mae = mean_absolute_error(test['Price / kg'], test['Predictions'])
print(f'MAE: {mae}')
# Out:
# RMSE: 9.233537627864687
# MSE: 85.25821712519301
# MAE: 8.97399562075735
